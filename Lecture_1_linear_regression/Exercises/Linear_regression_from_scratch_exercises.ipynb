# %% [markdown]
# ## Lecture 1 - Linear Regression
# In this notebook, you will be implementing your own linear regression model. For this you must complete all of the exercises below.
#
# If you have any question, feel free to ask in the Dojo's whatssapp group.

# %%
# Jupyter notebook display config
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# We will start importing the corresponding libraries.

# %%
# Import libraries 
# Scientific computation 
import numpy as np 
from numpy import r_, c_
# Visualization 
import matplotlib.pyplot as plt 
from matplotlib import style 
style.use('ggplot')
# Unit tests 
from unit_test import *

# %% [markdown]
# ### Create your dataset
# Let's create our dataset based on **N = 500** datapoints of a cosine function <br> y = A*cos(wx) <br>
# Where:
# * A = 1
# * w = 1

# %%
# Dataset (linear model)
# Features 
x = np.array([np.random.rand()*4 for i in range(500)]).reshape(-1, 1)
# Labels 
y = np.array([np.cos(i) for i in x]).reshape(-1, 1)

# %%
plt.scatter(x, y)
plt.title('Dataset')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ### Define the hypothesis
# Remember the hypothesis is a linear combination of **n** features parameterized by **w** weights. Where **n** is equal to **w**.
# The task is to build two functions. One that initilizes the learning parameters **w**. And another that computes a linear combination using the features and the learning parameters. <br> <br>
# ** Exercise: ** Complete the function initialize_weights, your task is to return a tensor of the same size as features in order to compute the hypothesis.

# %%
def initialize_weights(features):
    """ 
    Initialize the weights of the learning model
    :param features: tensor that contains the features of the model 
    : return: a tensor that contains random values with the same size of features
    """
    pass

# Unit test
test_initialize_weights(x, initialize_weights)
# Out:
# Tests passed

# %% [markdown]
# ** Exercise: ** Complete the function compute_hypothesis, your task is to return a tensor that contains a linear combination of features and learning parameters.

# %%
def compute_hypothesis(features, weights):
    """
    Compute the linear combination of the hypothesis
    :param features: tensor that contains the features of the model
    :param weights: tensor that contains the random-initialized 
                    learning parameters of the model
    : return: a tensor that matrix multiplies the features and the weights
    """
    pass

# Unit test 
test_compute_hypothesis(compute_hypothesis)
# Out:
# Tests passed

# %% [markdown]
# ### Cost function
# The next step is to program the cost function of the model. Remember that we are working on linear regression, so we are going to use the popular **mean squared error (MSE)** <br> <br>
#
# **Exercise: ** Complete the function cost_function, for this you will make use of the functions you implemented before.

# %%
def cost_function(hypothesis, labels, derivative = False):
    """
    Compute the cost function of a linear regression model 
    :param hypothesis: tensor that contains the linear combination of
                        features and learning parameters
    :param labels: tensor that contains the labels of the dataset
    :param derivative: boolean that controls the output of the derivative of the 
                        cost function
    : return: a value that represents the associated cost for the current hypothesis
            and labels
    """
    pass

# Unit test
test_cost_function(cost_function)
# Out:
# Tests passed

# %% [markdown]
# ### Learning algorithm
# The final step is to program the learning algorithm to minimize the cost function and so find the minium point in the **cost function vs learning parameters** function. <br>
# The algorithm that we are going to implement is going to be the batch gradient descent (BGD). <br>
#
# **Exercise: ** Tune the hyperparameters for BGD

# %%
# Hyperparameters 
epochs = 
learning_rate =

# %% [markdown]
# **Exercise: ** Complete the update rule in the implemantation of BGD.

# %%
# Support variables 
cost_history = []

# Initialize the learning parameters 
weights = initialize_weights(x)
print('weights initialized: {}'.format(weights))

# Compute the algorithm "epochs" times
for e in range(epochs):
    # Some feedback
    print('\n*Iteration number {}'.format(e))
    
    # Hypothesis
    hypothesis = compute_hypothesis(x, weights)
    #print( 'Hypothesis: {}'.format(hypothesis) )
    
    # Cost function
    cost, deriv = cost_function(hypothesis, y, derivative = True)
    cost_history.append(cost)
    print( 'Cost funtion: {}'.format(cost) )
    
    # Update weights
    ### IMPLEMENT YOUR CODE HERE!
# Out:
# weights initialized: [[ 0.09068975]]
#
# *Iteration number 0
# Cost funtion: 0.4301145075403382
#
# *Iteration number 1
# Cost funtion: 0.400202137546115
#
# *Iteration number 2
# Cost funtion: 0.37350436605338455
#
# *Iteration number 3
# Cost funtion: 0.3496757291778811
#
# *Iteration number 4
# Cost funtion: 0.32840788906998253
#
# *Iteration number 5
# Cost funtion: 0.3094256440839029
#
# *Iteration number 6
# Cost funtion: 0.2924833677228102
#
# *Iteration number 7
# Cost funtion: 0.2773618302805249
#
# *Iteration number 8
# Cost funtion: 0.2638653620524684
#
# *Iteration number 9
# Cost funtion: 0.2518193214083758
#
# *Iteration number 10
# Cost funtion: 0.24106783496413103
#
# *Iteration number 11
# Cost funtion: 0.23147178061099646
#
# *Iteration number 12
# Cost funtion: 0.22290698730303435
#
# *Iteration number 13
# Cost funtion: 0.21526262830832424
#
# *Iteration number 14
# Cost funtion: 0.20843978713296485
#
# *Iteration number 15
# Cost funtion: 0.20235017756120188
#
# *Iteration number 16
# Cost funtion: 0.19691500124925232
#
# *Iteration number 17
# Cost funtion: 0.19206392809031664
#
# *Iteration number 18
# Cost funtion: 0.18773418615690265
#
# *Iteration number 19
# Cost funtion: 0.18386974944449555
#
# *Iteration number 20
# Cost funtion: 0.18042061290613737
#
# *Iteration number 21
# Cost funtion: 0.17734214539700663
#
# *Iteration number 22
# Cost funtion: 0.174594512156229
#
# *Iteration number 23
# Cost funtion: 0.17214215935294802
#
# *Iteration number 24
# Cost funtion: 0.16995335402678372
#
# *Iteration number 25
# Cost funtion: 0.1679997734695998
#
# *Iteration number 26
# Cost funtion: 0.16625613873526043
#
# *Iteration number 27
# Cost funtion: 0.16469988753506568
#
# *Iteration number 28
# Cost funtion: 0.16331088228619672
#
# *Iteration number 29
# Cost funtion: 0.16207114953537594
#
# *Iteration number 30
# Cost funtion: 0.16096464738593547
#
# *Iteration number 31
# Cost funtion: 0.159977057918846
#
# *Iteration number 32
# Cost funtion: 0.15909560192167585
#
# *Iteration number 33
# Cost funtion: 0.15830887352810852
#
# *Iteration number 34
# Cost funtion: 0.15760669262828816
#
# *Iteration number 35
# Cost funtion: 0.15697997314021067
#
# *Iteration number 36
# Cost funtion: 0.1564206054376192
#
# *Iteration number 37
# Cost funtion: 0.15592135141304397
#
# *Iteration number 38
# Cost funtion: 0.15547575081812257
#
# *Iteration number 39
# Cost funtion: 0.15507803766926356
#
# *Iteration number 40
# Cost funtion: 0.15472306563695915
#
# *Iteration number 41
# Cost funtion: 0.15440624145329856
#
# *Iteration number 42
# Cost funtion: 0.15412346547598962
#
# *Iteration number 43
# Cost funtion: 0.15387107863979835
#
# *Iteration number 44
# Cost funtion: 0.15364581510896774
#
# *Iteration number 45
# Cost funtion: 0.15344476001794952
#
# *Iteration number 46
# Cost funtion: 0.15326531175361968
#
# *Iteration number 47
# Cost funtion: 0.15310514829091945
#
# *Iteration number 48
# Cost funtion: 0.15296219714631
#
# *Iteration number 49
# Cost funtion: 0.15283460856024533

# %% [markdown]
# ### Visualization of the cost function
# In order to convince ourselves that the algorithm is working and we have set the correct hyperparameters, we will plot the **cost function vs the number of epochs**.
#
# ** If you see that the cost function is decreasing over time, then the algorithm is working fine **

# %%
# Let's visualize the learning curve 
plt.scatter([i for i in range(epochs)], cost_history)
plt.title('Cost function vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Cost function')
plt.show()

# %% [markdown]
# ### Visualization of the result
# Finally, let's visualize the **machine learning model vs original data distribution**

# %%
plt.scatter(x, y, label='ground truth data', marker='*')
plt.scatter(x, [each*weights for each in x], label='learning algorithm', marker='^')
plt.title('Comparison')
plt.xlabel('x')
plt.ylabel('y / hypothesis')
plt.legend()
plt.show()

# %% [markdown]
# ### Adding more features
# At this point you will realize that it is impossible to fit a one parameter model into a non-linear function like a cos(x). So, what would you?
# <br>
# The answer is to add more parameters to the learning model, so it can fit our non-linear data distribution.
# <br>
# We will program the adding features part.

# %%
# Add polynomial features
print(x.shape)
x0 = np.ones_like(x)
x1 = x[:,0]**2
x2 = x[:,0]**3
xx = c_[x0, x, x1, x2]
print(xx.shape)
# Out:
# (500, 1)
# (500, 4)

# %%
# Hyperparameters 
epochs = 
learning_rate =

# %%
# Support variables 
cost_history = []

# Init weights
weights_xx = initialize_weights(xx)

# Compute the algorithm "epochs" times
for e in range(epochs):
    # Some feedback
    print('\n*Iteration number {}'.format(e))
    
    # Hypothesis
    hypothesis = compute_hypothesis(xx, weights_xx)
    #print( 'Hypothesis: {}'.format(hypothesis) )
    
    # Cost function
    cost, deriv = cost_function(hypothesis, y, derivative = True)
    cost_history.append(cost)
    print(deriv)
    print( 'Cost funtion: {}'.format(cost) )
    
    # Update weights
    weights_xx = weights_xx - learning_rate * deriv
    print('Updated weights:\n {}'.format(weights_xx))
# Out:
# *Iteration number 0
# 63.5260935188
# Cost funtion: 416.25183344132745
# Updated weights:
#  [[ 0.64042285]
#  [ 0.01489104]
#  [ 0.47485434]
#  [ 0.89515317]]
#
# *Iteration number 1
# 58.5775032606
# Cost funtion: 354.7347584982063
# Updated weights:
#  [[ 0.58184535]
#  [-0.04368646]
#  [ 0.41627684]
#  [ 0.83657567]]
#
# *Iteration number 2
# 54.0144009836
# Cost funtion: 302.374006019142
# Updated weights:
#  [[ 0.52783095]
#  [-0.09770086]
#  [ 0.36226244]
#  [ 0.78256127]]
#
# *Iteration number 3
# 49.8067577349
# Cost funtion: 257.80286014525416
# Updated weights:
#  [[ 0.47802419]
#  [-0.14750762]
#  [ 0.31245568]
#  [ 0.73275451]]
#
# *Iteration number 4
# 45.9268837734
# Cost funtion: 219.85891079739594
# Updated weights:
#  [[ 0.43209731]
#  [-0.1934345 ]
#  [ 0.2665288 ]
#  [ 0.68682763]]
#
# *Iteration number 5
# 42.3492463485
# Cost funtion: 187.55348898666568
# Updated weights:
#  [[ 0.38974806]
#  [-0.23578375]
#  [ 0.22417955]
#  [ 0.64447838]]
#
# *Iteration number 6
# 39.0503016737
# Cost funtion: 160.04567653333768
# Updated weights:
#  [[ 0.35069776]
#  [-0.27483405]
#  [ 0.18512925]
#  [ 0.60542808]]
#
# *Iteration number 7
# 36.0083399894
# Cost funtion: 136.62020542954676
# Updated weights:
#  [[ 0.31468942]
#  [-0.31084239]
#  [ 0.14912091]
#  [ 0.56941974]]
#
# *Iteration number 8
# 33.2033426943
# Cost funtion: 116.66866459793647
# Updated weights:
#  [[ 0.28148608]
#  [-0.34404573]
#  [ 0.11591757]
#  [ 0.5362164 ]]
#
# *Iteration number 9
# 30.6168506074
# Cost funtion: 99.67351896656325
# Updated weights:
#  [[ 0.25086923]
#  [-0.37466258]
#  [ 0.08530072]
#  [ 0.50559955]]
#
# *Iteration number 10
# 28.2318424909
# Cost funtion: 85.19451989772534
# Updated weights:
#  [[ 0.22263738]
#  [-0.40289442]
#  [ 0.05706887]
#  [ 0.4773677 ]]
#
# *Iteration number 11
# 26.0326230366
# Cost funtion: 72.85714902905735
# Updated weights:
#  [[ 0.19660476]
#  [-0.42892705]
#  [ 0.03103625]
#  [ 0.45133508]]
#
# *Iteration number 12
# 24.0047195781
# Cost funtion: 62.34279117062915
# Updated weights:
#  [[ 0.17260004]
#  [-0.45293177]
#  [ 0.00703153]
#  [ 0.42733036]]
#
# *Iteration number 13
# 22.1347868485
# Cost funtion: 53.38037746459175
# Updated weights:
#  [[ 0.15046525]
#  [-0.47506655]
#  [-0.01510325]
#  [ 0.40519558]]
#
# *Iteration number 14
# 20.4105191579
# Cost funtion: 45.73927875527908
# Updated weights:
#  [[ 0.13005473]
#  [-0.49547707]
#  [-0.03551377]
#  [ 0.38478506]]
#
# *Iteration number 15
# 18.8205694116
# Cost funtion: 39.223262058923254
# Updated weights:
#  [[ 0.11123416]
#  [-0.51429764]
#  [-0.05433434]
#  [ 0.36596449]]
#
# *Iteration number 16
# 17.3544744373
# Cost funtion: 33.66535103167051
# Updated weights:
#  [[ 0.09387969]
#  [-0.53165212]
#  [-0.07168882]
#  [ 0.34861001]]
#
# *Iteration number 17
# 16.0025861285
# Cost funtion: 28.923455150774753
# Updated weights:
#  [[ 0.0778771 ]
#  [-0.5476547 ]
#  [-0.0876914 ]
#  [ 0.33260743]]
#
# *Iteration number 18
# 14.7560079519
# Cost funtion: 24.876652574521053
# Updated weights:
#  [[ 0.0631211 ]
#  [-0.56241071]
#  [-0.10244741]
#  [ 0.31785142]]
#
# *Iteration number 19
# 13.6065364016
# Cost funtion: 21.422028865417246
# Updated weights:
#  [[ 0.04951456]
#  [-0.57601725]
#  [-0.11605395]
#  [ 0.30424488]]
#
# *Iteration number 20
# 12.5466070127
# Cost funtion: 18.47198840238741
# Updated weights:
#  [[ 0.03696795]
#  [-0.58856385]
#  [-0.12860056]
#  [ 0.29169828]]
#
# *Iteration number 21
# 11.569244581
# Cost funtion: 15.951967757044535
# Updated weights:
#  [[ 0.02539871]
#  [-0.6001331 ]
#  [-0.1401698 ]
#  [ 0.28012903]]
#
# *Iteration number 22
# 10.6680172608
# Cost funtion: 13.798490894768168
# Updated weights:
#  [[ 0.01473069]
#  [-0.61080112]
#  [-0.15083782]
#  [ 0.26946101]]
#
# *Iteration number 23
# 9.83699423752
# Cost funtion: 11.957515062288481
# Updated weights:
#  [[ 0.0048937 ]
#  [-0.62063811]
#  [-0.16067481]
#  [ 0.25962402]]
#
# *Iteration number 24
# 9.07070669869
# Cost funtion: 10.38302387702925
# Updated weights:
#  [[-0.00417701]
#  [-0.62970882]
#  [-0.16974552]
#  [ 0.25055331]]
#
# *Iteration number 25
# 8.36411184424
# Cost funtion: 9.035830641314622
# Updated weights:
#  [[-0.01254112]
#  [-0.63807293]
#  [-0.17810963]
#  [ 0.2421892 ]]
#
# *Iteration number 26
# 7.71255970089
# Cost funtion: 7.882560438222801
# Updated weights:
#  [[-0.02025368]
#  [-0.64578549]
#  [-0.18582219]
#  [ 0.23447664]]
#
# *Iteration number 27
# 7.11176252153
# Cost funtion: 6.894784271216973
# Updated weights:
#  [[-0.02736544]
#  [-0.65289725]
#  [-0.19293395]
#  [ 0.22736488]]
#
# *Iteration number 28
# 6.55776656832
# Cost funtion: 6.048282510707755
# Updated weights:
#  [[-0.03392321]
#  [-0.65945502]
#  [-0.19949172]
#  [ 0.22080711]]
#
# *Iteration number 29
# 6.04692609383
# Cost funtion: 5.322418312844301
# Updated weights:
#  [[-0.03997014]
#  [-0.66550194]
#  [-0.20553864]
#  [ 0.21476019]]
#
# *Iteration number 30
# 5.57587934906
# Cost funtion: 4.699604568747667
# Updated weights:
#  [[-0.04554602]
#  [-0.67107782]
#  [-0.21111452]
#  [ 0.20918431]]
#
# *Iteration number 31
# 5.14152646036
# Cost funtion: 4.164850402322871
# Updated weights:
#  [[-0.05068754]
#  [-0.67621935]
#  [-0.21625605]
#  [ 0.20404278]]
#
# *Iteration number 32
# 4.74100902974
# Cost funtion: 3.705375326534439
# Updated weights:
#  [[-0.05542855]
#  [-0.68096036]
#  [-0.22099706]
#  [ 0.19930177]]
#
# *Iteration number 33
# 4.37169132422
# Cost funtion: 3.3102809467189074
# Updated weights:
#  [[-0.05980024]
#  [-0.68533205]
#  [-0.22536875]
#  [ 0.19493008]]
#
# *Iteration number 34
# 4.03114293063
# Cost funtion: 2.9702716120004826
# Updated weights:
#  [[-0.06383139]
#  [-0.68936319]
#  [-0.22939989]
#  [ 0.19089894]]
#
# *Iteration number 35
# 3.71712276142
# Cost funtion: 2.6774167020200927
# Updated weights:
#  [[-0.06754851]
#  [-0.69308032]
#  [-0.23311702]
#  [ 0.18718181]]
#
# *Iteration number 36
# 3.42756430651
# Cost funtion: 2.4249483298655754
# Updated weights:
#  [[-0.07097607]
#  [-0.69650788]
#  [-0.23654458]
#  [ 0.18375425]]
#
# *Iteration number 37
# 3.16056203395
# Cost funtion: 2.2070891721110977
# Updated weights:
#  [[-0.07413663]
#  [-0.69966844]
#  [-0.23970514]
#  [ 0.18059369]]
#
# *Iteration number 38
# 2.91435884995
# Cost funtion: 2.0189059277337447
# Updated weights:
#  [[-0.07705099]
#  [-0.7025828 ]
#  [-0.2426195 ]
#  [ 0.17767933]]
#
# *Iteration number 39
# 2.68733453577
# Cost funtion: 1.856184580203857
# Updated weights:
#  [[-0.07973833]
#  [-0.70527014]
#  [-0.24530684]
#  [ 0.17499199]]
#
# *Iteration number 40
# 2.47799508535
# Cost funtion: 1.7153242089541785
# Updated weights:
#  [[-0.08221632]
#  [-0.70774813]
#  [-0.24778483]
#  [ 0.172514  ]]
#
# *Iteration number 41
# 2.28496287355
# Cost funtion: 1.5932465827810556
# Updated weights:
#  [[-0.08450129]
#  [-0.71003309]
#  [-0.25006979]
#  [ 0.17022904]]
#
# *Iteration number 42
# 2.10696759019
# Cost funtion: 1.4873191813240512
# Updated weights:
#  [[-0.08660825]
#  [-0.71214006]
#  [-0.25217676]
#  [ 0.16812207]]
#
# *Iteration number 43
# 1.94283788044
# Cost funtion: 1.3952896424968912
# Updated weights:
#  [[-0.08855109]
#  [-0.7140829 ]
#  [-0.2541196 ]
#  [ 0.16617923]]
#
# *Iteration number 44
# 1.79149363627
# Cost funtion: 1.3152299328611539
# Updated weights:
#  [[-0.09034259]
#  [-0.71587439]
#  [-0.25591109]
#  [ 0.16438774]]
#
# *Iteration number 45
# 1.65193888853
# Cost funtion: 1.2454887923171614
# Updated weights:
#  [[-0.09199452]
#  [-0.71752633]
#  [-0.25756303]
#  [ 0.1627358 ]]
#
# *Iteration number 46
# 1.52325525259
# Cost funtion: 1.1846512208283313
# Updated weights:
#  [[-0.09351778]
#  [-0.71904959]
#  [-0.25908629]
#  [ 0.16121254]]
#
# *Iteration number 47
# 1.40459588466
# Cost funtion: 1.1315039588880114
# Updated weights:
#  [[-0.09492238]
#  [-0.72045418]
#  [-0.26049088]
#  [ 0.15980795]]
#
# *Iteration number 48
# 1.29517990886
# Cost funtion: 1.0850060699216875
# Updated weights:
#  [[-0.09621756]
#  [-0.72174936]
#  [-0.26178606]
#  [ 0.15851277]]
#
# *Iteration number 49
# 1.19428727837
# Cost funtion: 1.04426386590827
# Updated weights:
#  [[-0.09741184]
#  [-0.72294365]
#  [-0.26298035]
#  [ 0.15731848]]
#
# *Iteration number 50
# 1.10125403701
# Cost funtion: 1.0085095307015293
# Updated weights:
#  [[-0.0985131 ]
#  [-0.7240449 ]
#  [-0.2640816 ]
#  [ 0.15621723]]
#
# *Iteration number 51
# 1.01546794979
# Cost funtion: 0.9770828918127565
# Updated weights:
#  [[-0.09952856]
#  [-0.72506037]
#  [-0.26509707]
#  [ 0.15520176]]
#
# *Iteration number 52
# 0.936364473949
# Cost funtion: 0.9494158733088292
# Updated weights:
#  [[-0.10046493]
#  [-0.72599674]
#  [-0.26603344]
#  [ 0.15426539]]
#
# *Iteration number 53
# 0.863423043786
# Cost funtion: 0.9250192321380262
# Updated weights:
#  [[-0.10132835]
#  [-0.72686016]
#  [-0.26689686]
#  [ 0.15340197]]
#
# *Iteration number 54
# 0.796163644908
# Cost funtion: 0.9034712394489176
# Updated weights:
#  [[-0.10212452]
#  [-0.72765632]
#  [-0.26769302]
#  [ 0.15260581]]
#
# *Iteration number 55
# 0.734143655343
# Cost funtion: 0.8844080188715538
# Updated weights:
#  [[-0.10285866]
#  [-0.72839047]
#  [-0.26842717]
#  [ 0.15187166]]
#
# *Iteration number 56
# 0.67695493273
# Cost funtion: 0.867515296608143
# Updated weights:
#  [[-0.10353561]
#  [-0.72906742]
#  [-0.26910412]
#  [ 0.15119471]]
#
# *Iteration number 57
# 0.624221128402
# Cost funtion: 0.8525213546576597
# Updated weights:
#  [[-0.10415984]
#  [-0.72969164]
#  [-0.26972834]
#  [ 0.15057049]]
#
# *Iteration number 58
# 0.575595210706
# Cost funtion: 0.8391910095322432
# Updated weights:
#  [[-0.10473543]
#  [-0.73026724]
#  [-0.27030394]
#  [ 0.14999489]]
#
# *Iteration number 59
# 0.530757181251
# Cost funtion: 0.8273204652265269
# Updated weights:
#  [[-0.10526619]
#  [-0.730798  ]
#  [-0.2708347 ]
#  [ 0.14946413]]
#
# *Iteration number 60
# 0.489411969054
# Cost funtion: 0.8167329116661569
# Updated weights:
#  [[-0.1057556 ]
#  [-0.73128741]
#  [-0.27132411]
#  [ 0.14897472]]
#
# *Iteration number 61
# 0.451287488731
# Cost funtion: 0.8072747589772096
# Updated weights:
#  [[-0.10620689]
#  [-0.73173869]
#  [-0.2717754 ]
#  [ 0.14852343]]
#
# *Iteration number 62
# 0.416132849957
# Cost funtion: 0.7988124141844327
# Updated weights:
#  [[-0.10662302]
#  [-0.73215483]
#  [-0.27219153]
#  [ 0.1481073 ]]
#
# *Iteration number 63
# 0.383716706396
# Cost funtion: 0.7912295207888398
# Updated weights:
#  [[-0.10700674]
#  [-0.73253854]
#  [-0.27257525]
#  [ 0.14772359]]
#
# *Iteration number 64
# 0.353825733254
# Cost funtion: 0.7844245934561129
# Updated weights:
#  [[-0.10736056]
#  [-0.73289237]
#  [-0.27292907]
#  [ 0.14736976]]
#
# *Iteration number 65
# 0.32626322343
# Cost funtion: 0.7783089900743909
# Updated weights:
#  [[-0.10768683]
#  [-0.73321863]
#  [-0.27325533]
#  [ 0.1470435 ]]
#
# *Iteration number 66
# 0.30084779302
# Cost funtion: 0.7728051719751068
# Updated weights:
#  [[-0.10798767]
#  [-0.73351948]
#  [-0.27355618]
#  [ 0.14674265]]
#
# *Iteration number 67
# 0.27741218766
# Cost funtion: 0.767845210376294
# Updated weights:
#  [[-0.10826509]
#  [-0.73379689]
#  [-0.27383359]
#  [ 0.14646524]]
#
# *Iteration number 68
# 0.255802181861
# Cost funtion: 0.7633695032935623
# Updated weights:
#  [[-0.10852089]
#  [-0.7340527 ]
#  [-0.2740894 ]
#  [ 0.14620943]]
#
# *Iteration number 69
# 0.235875564071
# Cost funtion: 0.7593256724308717
# Updated weights:
#  [[-0.10875676]
#  [-0.73428857]
#  [-0.27432527]
#  [ 0.14597356]]
#
# *Iteration number 70
# 0.217501200816
# Cost funtion: 0.75566761404828
# Updated weights:
#  [[-0.10897426]
#  [-0.73450607]
#  [-0.27454277]
#  [ 0.14575606]]
#
# *Iteration number 71
# 0.200558173725
# Cost funtion: 0.7523546816235717
# Updated weights:
#  [[-0.10917482]
#  [-0.73470663]
#  [-0.27474333]
#  [ 0.1455555 ]]
#
# *Iteration number 72
# 0.184934983792
# Cost funtion: 0.7493509813782248
# Updated weights:
#  [[-0.10935976]
#  [-0.73489157]
#  [-0.27492827]
#  [ 0.14537056]]
#
# *Iteration number 73
# 0.170528817625
# Cost funtion: 0.7466247645098517
# Updated weights:
#  [[-0.10953029]
#  [-0.73506209]
#  [-0.27509879]
#  [ 0.14520004]]
#
# *Iteration number 74
# 0.157244870842
# Cost funtion: 0.7441479023348163
# Updated weights:
#  [[-0.10968753]
#  [-0.73521934]
#  [-0.27525604]
#  [ 0.14504279]]
#
# *Iteration number 75
# 0.144995724186
# Cost funtion: 0.7418954325571889
# Updated weights:
#  [[-0.10983253]
#  [-0.73536433]
#  [-0.27540104]
#  [ 0.14489779]]
#
# *Iteration number 76
# 0.133700768232
# Cost funtion: 0.739845166595498
# Updated weights:
#  [[-0.10996623]
#  [-0.73549804]
#  [-0.27553474]
#  [ 0.14476409]]
#
# *Iteration number 77
# 0.123285672914
# Cost funtion: 0.7379773493610062
# Updated weights:
#  [[-0.11008951]
#  [-0.73562132]
#  [-0.27565802]
#  [ 0.14464081]]
#
# *Iteration number 78
# 0.113681898368
# Cost funtion: 0.7362743641281191
# Updated weights:
#  [[-0.1102032 ]
#  [-0.735735  ]
#  [-0.2757717 ]
#  [ 0.14452713]]
#
# *Iteration number 79
# 0.104826243886
# Cost funtion: 0.7347204762009506
# Updated weights:
#  [[-0.11030802]
#  [-0.73583983]
#  [-0.27587653]
#  [ 0.1444223 ]]
#
# *Iteration number 80
# 0.0966604320036
# Cost funtion: 0.7333016099872616
# Updated weights:
#  [[-0.11040468]
#  [-0.73593649]
#  [-0.27597319]
#  [ 0.14432564]]
#
# *Iteration number 81
# 0.089130724986
# Cost funtion: 0.7320051548651325
# Updated weights:
#  [[-0.11049381]
#  [-0.73602562]
#  [-0.27606232]
#  [ 0.14423651]]
#
# *Iteration number 82
# 0.0821875711898
# Cost funtion: 0.7308197958884793
# Updated weights:
#  [[-0.110576  ]
#  [-0.73610781]
#  [-0.27614451]
#  [ 0.14415432]]
#
# *Iteration number 83
# 0.0757852789725
# Cost funtion: 0.7297353659417226
# Updated weights:
#  [[-0.11065179]
#  [-0.73618359]
#  [-0.27622029]
#  [ 0.14407854]]
#
# *Iteration number 84
# 0.0698817160039
# Cost funtion: 0.728742716435783
# Updated weights:
#  [[-0.11072167]
#  [-0.73625348]
#  [-0.27629018]
#  [ 0.14400865]]
#
# *Iteration number 85
# 0.0644380320012
# Cost funtion: 0.7278336040493096
# Updated weights:
#  [[-0.11078611]
#  [-0.73631791]
#  [-0.27635461]
#  [ 0.14394422]]
#
# *Iteration number 86
# 0.059418403062
# Cost funtion: 0.7270005913709626
# Updated weights:
#  [[-0.11084552]
#  [-0.73637733]
#  [-0.27641403]
#  [ 0.1438848 ]]
#
# *Iteration number 87
# 0.0547897959139
# Cost funtion: 0.7262369595995015
# Updated weights:
#  [[-0.11090031]
#  [-0.73643212]
#  [-0.27646882]
#  [ 0.14383001]]
#
# *Iteration number 88
# 0.0505217505283
# Cost funtion: 0.725536631715866
# Updated weights:
#  [[-0.11095084]
#  [-0.73648264]
#  [-0.27651934]
#  [ 0.14377949]]
#
# *Iteration number 89
# 0.0465861796685
# Cost funtion: 0.7248941047617743
# Updated weights:
#  [[-0.11099742]
#  [-0.73652923]
#  [-0.27656593]
#  [ 0.1437329 ]]
#
# *Iteration number 90
# 0.0429571840526
# Cost funtion: 0.7243043900480393
# Updated weights:
#  [[-0.11104038]
#  [-0.73657219]
#  [-0.27660889]
#  [ 0.14368994]]
#
# *Iteration number 91
# 0.0396108819152
# Cost funtion: 0.7237629602774596
# Updated weights:
#  [[-0.11107999]
#  [-0.7366118 ]
#  [-0.2766485 ]
#  [ 0.14365033]]
#
# *Iteration number 92
# 0.0365252518456
# Cost funtion: 0.7232657027057351
# Updated weights:
#  [[-0.11111651]
#  [-0.73664832]
#  [-0.27668502]
#  [ 0.14361381]]
#
# *Iteration number 93
# 0.0336799878691
# Cost funtion: 0.7228088775827166
# Updated weights:
#  [[-0.11115019]
#  [-0.736682  ]
#  [-0.2767187 ]
#  [ 0.14358013]]
#
# *Iteration number 94
# 0.0310563658166
# Cost funtion: 0.7223890812183672
# Updated weights:
#  [[-0.11118125]
#  [-0.73671306]
#  [-0.27674976]
#  [ 0.14354907]]
#
# *Iteration number 95
# 0.0286371201047
# Cost funtion: 0.7220032131054439
# Updated weights:
#  [[-0.11120989]
#  [-0.7367417 ]
#  [-0.2767784 ]
#  [ 0.14352043]]
#
# *Iteration number 96
# 0.026406330114
# Cost funtion: 0.7216484466062683
# Updated weights:
#  [[-0.11123629]
#  [-0.7367681 ]
#  [-0.2768048 ]
#  [ 0.14349403]]
#
# *Iteration number 97
# 0.0243493154178
# Cost funtion: 0.7213222027757685
# Updated weights:
#  [[-0.11126064]
#  [-0.73679245]
#  [-0.27682915]
#  [ 0.14346968]]
#
# *Iteration number 98
# 0.0224525391737
# Cost funtion: 0.7210221269487959
# Updated weights:
#  [[-0.1112831 ]
#  [-0.7368149 ]
#  [-0.2768516 ]
#  [ 0.14344723]]
#
# *Iteration number 99
# 0.0207035190392
# Cost funtion: 0.720746067767806
# Updated weights:
#  [[-0.1113038 ]
#  [-0.73683561]
#  [-0.27687231]
#  [ 0.14342652]]

# %%
plt.scatter(x, y, label='ground truth data', marker='*')
plt.scatter(x, [compute_hypothesis(each.reshape(1,4), weights_xx.reshape(4,1)) for each in xx], label='learning algorithm', marker='^')
plt.title('Comparison')
plt.xlabel('x')
plt.ylabel('y / hypothesis')
plt.legend()
plt.show()

# %% [markdown]
# ## Using scikit-learn to fit our model

# %%
from sklearn import linear_model
clf = linear_model.LinearRegression(fit_intercept=True)
clf.fit(xx, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
weights_xx = clf.coef_
weights_xx
# Out:
# array([[ 0.        , -0.06331566, -0.56232447,  0.11935525]])

# %%
plt.scatter(x, y, label='ground truth data', marker='*')
plt.scatter(x, [compute_hypothesis(each.reshape(1,4), weights_xx.reshape(4,1)) for each in xx], label='learning algorithm', marker='^')
plt.title('Comparison')
plt.xlabel('x')
plt.ylabel('y / hypothesis')
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusions
# What can we conclude from the exercises?
# # Fill this space with your answers
